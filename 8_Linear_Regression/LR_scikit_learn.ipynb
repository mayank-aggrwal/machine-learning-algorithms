# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
# %matplotlib notebook

# %%
X, y = make_regression()

# %%
print(X.shape, y.shape)
# Out:
# (100, 100) (100,)

# %%
X, y = make_regression(n_samples=1000, n_features=2, n_informative=2, noise=10 ,random_state=1)

# %%
print(X.shape, y.shape)
# Out:
# (1000, 2) (1000,)

# %%
dfX = pd.DataFrame(X, columns=['f1', 'f2'])
dfX
# Out:
#            f1        f2
# 0   -0.915424 -1.945047
# 1   -2.304908 -0.592461
# 2   -0.437509 -0.781912
# 3   -1.061797 -0.569149
# 4    0.008359  0.034066
# ..        ...       ...
# 995 -0.479185 -0.418938
# 996 -1.899463 -1.168961
# 997 -0.468674  0.021863
# 998 -0.442655  0.557533
# 999 -0.139712  0.853282
#
# [1000 rows x 2 columns]

# %%
dfY = pd.DataFrame(y, columns=['y'])
dfY
# Out:
#               y
# 0   -198.367142
# 1    -71.877706
# 2    -86.970324
# 3    -69.649240
# 4     18.274576
# ..          ...
# 995  -38.361458
# 996 -146.401642
# 997  -19.200111
# 998   47.016140
# 999   70.677107
#
# [1000 rows x 1 columns]

# %%
print(type(X[:, 0]))
print(type(y))

print(X[:, 0].shape)
print(y.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (1000,)
# (1000,)

# %%
plt.style.use('seaborn')

# %%
plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], y)

plt.subplot(1, 2, 2)
plt.scatter(X[:, 1], y)

plt.show()

# %%
from mpl_toolkits import mplot3d

fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection='3d')

# Creating Plot
ax.scatter3D(X[:, 0], X[:, 1], y, color='green')
plt.title('3D scatter plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Linear Regression

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([16.62437639, 87.99042847])

# %%
model.intercept_
# Out:
# -0.21766413760018422

# %%
print(type(X[0]))
print(X[0].shape)
# Out:
# <class 'numpy.ndarray'>
# (2,)

# %%
model.predict([X[0], X[1]])
# Out:
# array([-186.58153868,  -90.66624357])

# %%
y[0], y[1]
# Out:
# (-198.36714169030483, -71.87770558832477)

# %%
# R2 score
model.score(X, y)
# Out:
# 0.988401838483157

# %%
# model.score?
